# %% [markdown]
# # Vector Embeddings Tutorial with the t-SNE Algorithm
# Instructor: Zion Pibowei
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/17HjVut5EGaezO5x_-RDPr4J8_S5i8Reu)

# %%
! pip install pandas scikit-learn matplotlib seaborn
# Out:
# ...
#      ------------------------------------ 280.0/280.0 kB 308.3 kB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiohttp 3.9.3 requires aiosignal>=1.1.2, which is not installed.
# aiohttp 3.9.3 requires frozenlist>=1.1.1, which is not installed.
# aiohttp 3.9.3 requires multidict<7.0,>=4.5, which is not installed.
# aiohttp 3.9.3 requires yarl<2.0,>=1.0, which is not installed.
# aiohttp 3.9.3 requires async-timeout<5.0,>=4.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.

# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import time

import warnings
warnings.filterwarnings("ignore")

# %%
# Download Spotify dataset at https://www.kaggle.com/datasets/zaheenhamidani/ultimate-spotify-tracks-db?resource=download
filepath = "SpotifyFeatures.csv"
df = pd.read_csv(filepath)

# %%
len(df)
# Out:
# 232725

# %%
df_subset = df.sample(20000, random_state=42)

# %%
df_subset.head()
# Out:
#              genre        artist_name                             track_name  \
# 788        Country  A Thousand Horses                       My Time's Comin'
# 207109  Soundtrack  Mark Mothersbaugh                             House Tour
# 138644      Reggae    Unified Highway  We Can't Fall (Remix) [feat. J. Patz]
# 37164   Electronic       Stooki Sound                    Endz - Original Mix
# 174351      Comedy         Bill Hicks                   I Love My Job (Live)
#
#                       track_id  popularity  acousticness  danceability  \
# 788     16zol4GvHyTER5irYODUk0          45       0.00192         0.327
# 207109  6ac5gUfGTckpdGQCyWsdh2          25       0.93200         0.253
# 138644  09Yz6koF1Y15n1012t1UX6          19       0.03310         0.821
# 37164   3dzEZARDL4ZwICMKVta7Xn          29       0.00428         0.745
# 174351  39Z1G5384UgGa5vmW6WyxC          17       0.96500         0.502
#
# ...

# %%
df_subset.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
feature_cols = [
    'popularity','acousticness', 'danceability', 'duration_ms', 'energy',
    'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence'
]

# %%
X = df_subset[feature_cols].values
df_subset[feature_cols]
# Out:
#         popularity  acousticness  danceability  duration_ms  energy  \
# 788             45       0.00192         0.327       194107  0.8350
# 207109          25       0.93200         0.253       102920  0.0798
# 138644          19       0.03310         0.821       225437  0.7370
# 37164           29       0.00428         0.745       225400  0.7720
# 174351          17       0.96500         0.502       287973  0.8040
# ...            ...           ...           ...          ...     ...
# 211150          29       0.96000         0.220       282707  0.1420
# 154295          54       0.25000         0.507       199920  0.6170
# 228487          42       0.16100         0.708       236493  0.4000
# 231330          42       0.05130         0.504       369827  0.5050
# 232516          42       0.80300         0.476       291501  0.3410
#
#         instrumentalness  liveness  loudness  speechiness    tempo  valence
# ...

# %%
# Apply t-SNE to reduce to 2D
start_time = time.time()
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_2d = tsne.fit_transform(X)

print(f"Fitted tSNE algorithm to 200 samples of the data in {time.time()-start_time} seconds")
# Out:
# Fitted tSNE algorithm to 200 samples of the data in 0.9436333179473877 seconds

# %%
# Apply t-SNE to reduce to 2D
start_time = time.time()
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_2d = tsne.fit_transform(X)

print(f"Fitted tSNE algorithm to 20000 samples of the data in {time.time()-start_time} seconds")
# Out:
# Fitted tSNE algorithm to 20000 samples of the data in 170.774804353714 seconds

# %%
X_2d
# Out:
# array([[  4.8467298,  84.43301  ],
#        [-28.939594 ,  -9.474218 ],
#        [ 41.83332  ,  19.566133 ],
#        ...,
#        [-27.195354 , -70.30074  ],
#        [ 24.755507 ,  -4.2599454],
#        [ 70.76282  , -28.65167  ]], dtype=float32)

# %%
# Add the 2D coordinates back to the dataframe
df_subset['x'] = X_2d[:,0]
df_subset['y'] = X_2d[:,1]

# %%
# Plot with color based on genre
plt.figure(figsize=(12,8))
sns.scatterplot(data=df_subset, x='x', y='y', hue='genre', palette='tab10', s=70, alpha=0.8)
plt.title("t-SNE Visualization of Spotify Song Embeddings (Kaggle Dataset)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.show()
